# %% [markdown]
# <a href="https://colab.research.google.com/github/aksamps/lp4ml/blob/main/dataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd #panel data
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.array(['a',2,'c',4,5])
print(type(a))
print(a)
pd.Series(a)
# Out:
# <class 'numpy.ndarray'>
# ['a' '2' 'c' '4' '5']
# 0    a
# 1    2
# 2    c
# 3    4
# 4    5
# dtype: object

# %%
table = {"name": ["abc", "def", "nji","jk" ],
         "age": [1,2,3,9],
         "title" : ["mr", "kk", "jk","ll"],
         }
t=pd.DataFrame(table)
#print(type(t))
print(t)
print(type(t.shape))
# Out:
#   name  age title
# 0  abc    1    mr
# 1  def    2    kk
# 2  nji    3    jk
# 3   jk    9    ll
# <class 'tuple'>

# %%
data=pd.read_csv("Housing.csv")
data.shape
# Out:
# (545, 13)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
data.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
data.describe(include="O")
# Out:
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishingstatus
# count               545
# unique                3
# top      semi-furnished
# freq                227

# %%
data.loc[0]
# Out:
# price                13300000
# area                     7420
# bedrooms                    4
# bathrooms                   2
# stories                     3
# mainroad                  yes
# guestroom                  no
# basement                   no
# hotwaterheating            no
# airconditioning           yes
# parking                     2
# prefarea                  yes
# furnishingstatus    furnished
# Name: 0, dtype: object

# %%
print(data.loc[0,"prefarea"])
data.loc[0,"furnishingstatus"]
# Out:
# yes
# 'furnished'

# %%
data.iloc[1]
# Out:
# price                12250000
# area                     8960
# bedrooms                    4
# bathrooms                   4
# stories                     4
# mainroad                  yes
# guestroom                  no
# basement                   no
# hotwaterheating            no
# airconditioning           yes
# parking                     3
# prefarea                   no
# furnishingstatus    furnished
# Name: 1, dtype: object

# %%
data.iloc[1,2]
# Out:
# np.int64(4)

# %%
data.loc[2:5,["furnishingstatus","prefarea"]]
# Out:
#   furnishingstatus prefarea
# 2   semi-furnished      yes
# 3        furnished      yes
# 4        furnished       no
# 5   semi-furnished      yes

# %%
data.iloc[2:5,[0,1]]
# Out:
#       price  area
# 2  12250000  9960
# 3  12215000  7500
# 4  11410000  7420

# %%
data.iloc[2:5,0:3]
# Out:
#       price  area  bedrooms
# 2  12250000  9960         3
# 3  12215000  7500         4
# 4  11410000  7420         4
