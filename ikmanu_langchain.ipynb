# %% [markdown]
# <a href="https://colab.research.google.com/github/aksamps/lp4ml/blob/main/ikmanu_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 uninstall \
  langchain-text-splitters \
  langchain-openai>=0.2.3 \
  langchain-experimental>=0.3.4 \
  langchain-chroma \
  requests==2.32.4 \
  langchain-community>=0.3.29 \
  langchain-huggingface>=0.3.1
