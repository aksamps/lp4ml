# %% [markdown]
# <a href="https://colab.research.google.com/github/aksamps/lp4ml/blob/main/lp4colab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print("learn python")
# Out:
# learn python

# %%
import requests
import json
import pandas as pd
d=pd.DataFrame(json.loads(requests.get("https://api.mfapi.in/mf/152726").content)['data'])
d
d.to_csv("fffffffff.csv",index=True)

# %%
import numpy as np

# %% [markdown]
# # **Python Variables**

# %% [markdown]
# #### id function

# %%
#id funtion returns the identity of the object.
#This is guaranteed to be unique among simultaneously existing objects.
#in (CPython uses the object's memory address.)
#11654408 -> is the identity of value 2 , not x, x is just a label at that point
#11654440 -> is the identity of value 3 , not x, x is just a label at that point
x=2
print(id(x))
x=3
print(id(x))
# Out:
# 11654408
# 11654440

# %% [markdown]
# #### Print Special charachers in Python

# %%
#list the special characters in python
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
